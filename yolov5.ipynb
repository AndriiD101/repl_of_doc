# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-1dbcf436c2dc> in <cell line: 0>()
#       1 # Load the Drive helper and mount
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
# ...

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17372, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 17372 (delta 42), reused 20 (delta 20), pack-reused 17313 (from 3)
# Receiving objects: 100% (17372/17372), 16.24 MiB | 17.02 MiB/s, done.
# Resolving deltas: 100% (11904/11904), done.

# %%
# !pip install -r /content/drive/MyDrive/yolov5/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.5/974.5 kB 53.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# %cd yolov5
# Out:
# /content/drive/MyDrive/yolov5

# %%
# !python3 train.py --img 224 --batch 16 --epochs 100 --optimizer Adam \
--data "/content/drive/MyDrive/replic_of_doc/RiceDiseaseDataset_yolo_test/rice_detection.yaml" \
--cfg "/content/drive/MyDrive/yolov5/models/yolov5x.yaml" \
--name "yolov5x_default" \
--weights ""
# Out:
# Streaming output truncated to the last 5000 lines.
#       36/99      5.77G    0.07766    0.02302    0.01256         49        224:  92% 34/37 [00:06<00:00,  6.83it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       36/99      5.77G    0.07757    0.02309    0.01241        123        224:  95% 35/37 [00:06<00:00,  6.32it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       36/99      5.77G    0.07773    0.02305    0.01249        105        224:  97% 36/37 [00:06<00:00,  6.70it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# !python3 train.py --img 224 --batch 16 --epochs 100 --optimizer Adam \
--data "/content/drive/MyDrive/replic_of_doc/RiceDiseaseDataset_yolo_test/rice_detection.yaml" \
--cfg "/content/drive/MyDrive/yolov5/models/hub/yolov5-bifpn.yaml" \
--name "yolov5x_bifapn" \
--weights ""
# Out:
# Streaming output truncated to the last 5000 lines.
#       36/99      3.45G    0.07032    0.02242   0.007628         49        224:  92% 34/37 [00:05<00:00,  7.72it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       36/99      3.45G    0.07024    0.02249   0.007477        123        224:  95% 35/37 [00:05<00:00,  7.01it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       36/99      3.45G    0.07042    0.02247    0.00758        105        224:  97% 36/37 [00:05<00:00,  7.40it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# !python3 train.py --img 224 --batch 16 --epochs 100 --optimizer Adam \
--data "/content/drive/MyDrive/replic_of_doc/RiceDiseaseDataset_yolo_test/rice_detection.yaml" \
--cfg "/content/drive/MyDrive/yolov5/models/hub/yolov5-bifpn.yaml" \
--name "yolov5x_bifapn" \
--weights "yolov5x.pt"
# Out:
# Streaming output truncated to the last 5000 lines.
#       36/99      3.65G    0.07072    0.02247   0.008089         49        224:  92% 34/37 [00:05<00:00,  7.70it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       36/99      3.65G    0.07066    0.02254   0.007954        123        224:  95% 35/37 [00:05<00:00,  7.02it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       36/99      3.65G    0.07075    0.02253   0.008066        105        224:  97% 36/37 [00:05<00:00,  7.38it/s]/content/drive/MyDrive/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...
